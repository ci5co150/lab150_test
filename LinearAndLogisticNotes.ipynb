# %% [markdown]
# <a href="https://colab.research.google.com/github/ci5co150/lab150_test/blob/main/LinearAndLogisticNotes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Linera Regression
#
# By Francisco Gomez
#
# Csci191T Fall 2021

# %% [markdown]
# **What is Linear Regression**
#
# Linear regression is used to predict an outcome variable, or dependent variable. By using a set of independet variables.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Elements of linear regresion**
#
# 1. A function eg:
#     - cointaing weights
#
#     - hw(X) = W1x+ w0

# %% [markdown]
#  2. Empirical Loss = ZUM((yj - hw(xj))^2) from 1 to N
#
#  ![image.png](data:image/png;base64,...)

# %% [markdown]
#   3. Gradient Descent
#
#      ![image.png](data:image/png;base64,...)

# %% [markdown]
#   and where alpha is the lenght of steps

# %% [markdown]
#    4. update rule using calculus
#
#    ![image.png](data:image/png;base64,...)

# %% [markdown]
#   5. Model update
#
#      ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Class Assignment**

# %%
import random
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import math

# %%
data = [((1, -2), 1), ((1, -1), 3), ((1, 0), 5), ((1, 1), 7), ((1, 2), 9), ((1, 3), 11), ((1, 4), 13), ((1, 5), 15), ((1, 6), 17), ((1, 7), 19), ((1, 8), 21), ((1, 9), 23), ((1, 10), 25)]
data2 = [((1, -2), 6.39), ((1, -1), 16.51), ((1, 0), -3.11), ((1, 1), 10.79), ((1, 2), 11.62), ((1, 3), 23.24), ((1, 4), 18.27), ((1, 5), 27.58), ((1, 6), 22.21), ((1, 7), 5.12), ((1, 8), 8.86), ((1, 9), 10.69), ((1, 10), 14.82)]
X = [d for d,_ in data]
print(data)
alpha=0.01
model=[0, 0]
Errors = []
# Out:
# [((1, -2), 1), ((1, -1), 3), ((1, 0), 5), ((1, 1), 7), ((1, 2), 9), ((1, 3), 11), ((1, 4), 13), ((1, 5), 15), ((1, 6), 17), ((1, 7), 19), ((1, 8), 21), ((1, 9), 23), ((1, 10), 25)]

# %%
# Evaluate Model
def linearRegression(d, model, a, j):
  for i in range(j):
    yPredicted = [F(model, x) for x in X]
    Error = sum([(r-y)**2.0 for r,y in zip(Y, yPredicted)])
    Errors.append([model, Error])
    #print("Iterations=",i+1,":=",Errors[i])
    deltaX0 = 1/len(Y)*sum( [(-2*((r-y))*x[0]) for r,y,x in zip(Y, yPredicted, X)] )
    deltaX1 = 1/len(Y)*sum( [(-2*((r-y))*x[1]) for r,y,x in zip(Y, yPredicted, X)] )
    model = [model[0]-alpha*deltaX0, model[1]-alpha*deltaX1]
    """
    print(model)

    print(deltaX0)
    print(deltaX1)
    dataX1 = [x[1] for x, y in data]
    """
    if(i%10 == 0):
      print("Iteration: ", i)
      print("With Model=", model, "Error=", Error)
      plt.plot(dataX1, yPredicted, "g")
      plt.plot(dataX1, Y, "g+")
      plt.show()

linearRegression(data, model, alpha, 110)
# Out:
# Iteration:  0
# With Model= [0.26, 1.6] Error= 2925.0
# Iteration:  10
# With Model= [0.8033824085264076, 2.5681484036730104] Error= 108.85941462527283
# Iteration:  20
# With Model= [1.1726402858426157, 2.5182330686104932] Error= 90.54573057939618
# Iteration:  30
# With Model= [1.5093982034499478, 2.4726352991385263] Error= 75.31301440968245
# Iteration:  40
# With Model= [1.8165257998070254, 2.431049534895892] Error= 62.64293305910685
# Iteration:  50
# With Model= [2.096630158928189, 2.3931227774828208] Error= 52.104368587632145
# Iteration:  60
# With Model= [2.352088974512696, 2.358533081849012] Error= 43.33873101622189
# Iteration:  70
# With Model= [2.5850707341132684, 2.326986829924318] Error= 36.04775678142021
# Iteration:  80
# With Model= [2.7975531265583338, 2.2982162382130795] Error= 29.983359883934746
# Iteration:  90
# With Model= [2.9913398297602605, 2.2719770846873075] Error= 24.93919040179812
# Iteration:  100
# With Model= [3.1680758214146314, 2.2480466356837114] Error= 20.74361313424352

# %% [markdown]
# **Reset the model to test the Training Data 2 with Noise**
#
# [((1, -2), 6.39), ((1, -1), 16.51), ((1, 0), -3.11), ((1, 1), 10.79), ((1, 2), 11.62), ((1, 3), 23.24), ((1, 4), 18.27), ((1, 5), 27.58), ((1, 6), 22.21), ((1, 7), 5.12), ((1, 8), 8.86), ((1, 9), 10.69), ((1, 10), 14.82)]

# %%
model=[0, 0]
linearRegression(data2, model, alpha, 110)
# Out:
# Iteration:  0
# With Model= [0.26, 1.6] Error= 2925.0
# Iteration:  10
# With Model= [0.8033824085264076, 2.5681484036730104] Error= 108.85941462527283
# Iteration:  20
# With Model= [1.1726402858426157, 2.5182330686104932] Error= 90.54573057939618
# Iteration:  30
# With Model= [1.5093982034499478, 2.4726352991385263] Error= 75.31301440968245
# Iteration:  40
# With Model= [1.8165257998070254, 2.431049534895892] Error= 62.64293305910685
# Iteration:  50
# With Model= [2.096630158928189, 2.3931227774828208] Error= 52.104368587632145
# Iteration:  60
# With Model= [2.352088974512696, 2.358533081849012] Error= 43.33873101622189
# Iteration:  70
# With Model= [2.5850707341132684, 2.326986829924318] Error= 36.04775678142021
# Iteration:  80
# With Model= [2.7975531265583338, 2.2982162382130795] Error= 29.983359883934746
# Iteration:  90
# With Model= [2.9913398297602605, 2.2719770846873075] Error= 24.93919040179812
# Iteration:  100
# With Model= [3.1680758214146314, 2.2480466356837114] Error= 20.74361313424352
