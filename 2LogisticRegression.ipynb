# %% [markdown]
# <a href="https://colab.research.google.com/github/ci5co150/lab150_test/blob/main/2LogisticRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
### Includes
# %matplotlib inline
import matplotlib.pyplot as plt
import math

# %% [markdown]
# **Logistic Regression**

# %%
data0 = [((1,2,3),0), ((1,3,4),0), ((1,4,5),0), ((1,5,6),1), ((1,6,7),1), ((1,8,9),1) ]
data1 = [((1, 0, 0), 1), ((1, 1, 7), 0), ((1, -3, -2), 0), ((1, 8, 9), 1), ((1, 4, 3), 1), ((1, 5, -2), 1), ((1, 0, 0), 1), ((1, 6, 9), 1), ((1, 4, 2), 1), ((1, 1, -9), 1), ((1, -7, 7), 0), ((1, 0, -1), 1), ((1, 9, -4), 1), ((1, 1, 0), 1), ((1, -2, -5), 1), ((1, 2, 3), 1), ((1, -7, 2), 0), ((1, -3, 0), 0), ((1, 5, 0), 1), ((1, 0, -3), 1), ((1, -2, 3), 0), ((1, 9, 6), 1), ((1, 0, -8), 1), ((1, 0, 2), 0), ((1, -8, 6), 0), ((1, 1, 9), 0), ((1, 0, 5), 0), ((1, -4, 9), 0), ((1, 8, 2), 1), ((1, 2, 6), 0)]
data2 = [((1, 0, 0), 0), ((1, 1, 7), 0), ((1, -3, -2), 0), ((1, 8, 9), 1), ((1, 4, 3), 1), ((1, 5, -2), 1), ((1, 0, 0), 0), ((1, 6, 9), 1), ((1, 4, 2), 1), ((1, 1, -9), 1), ((1, -7, 7), 0), ((1, 0, -1), 1), ((1, 9, -4), 1), ((1, 1, 0), 1), ((1, -2, -5), 1), ((1, 2, 3), 1), ((1, -7, 2), 0), ((1, -3, 0), 0), ((1, 5, 0), 1), ((1, 0, -3), 1), ((1, -2, 3), 0), ((1, 9, 6), 1), ((1, 0, -8), 1), ((1, 0, 2), 1), ((1, -8, 6), 0), ((1, 1, 9), 0), ((1, 0, 5), 0), ((1, -4, 9), 0), ((1, 8, 2), 1), ((1, 2, 6), 0)]
data3 = [((1, 2, 7), 0), ((1, 19, 72), 0), ((1, -39, -20), 0), ((1, 86, 95), 1), ((1, 45, 37), 1), ((1, 52, -23), 1), ((1, -8, -8), 0), ((1, 67, 93), 1), ((1, 46, 21), 1), ((1, 18, -97), 1), ((1, -78, 70), 0), ((1, -9, -17), 1), ((1, 94, -40), 1), ((1, 11, -3), 1), ((1, -24, -59), 1), ((1, 25, 33), 1), ((1, -71, 23), 0), ((1, -34, -7), 0), ((1, 55, -3), 1), ((1, -5, -33), 1), ((1, -22, 38), 0), ((1, 94, 66), 1), ((1, 4, -89), 1), ((1, -9, 26), 0), ((1, -83, 61), 0), ((1, 19, 98), 0), ((1, -1, 55), 0), ((1, -43, 90), 0), ((1, 86, 27), 1), ((1, 24, 69), 0)]

# %%
from sklearn.linear_model import LogisticRegression
#log_reg = LogisticRegression(random_state=42, solver='sag', penalty='none', max_iter=10000, fit_intercept=False)
#log_reg = LogisticRegression(random_state=42, penalty='none', verbose=1, fit_intercept=False)
#og_reg.fit(X, Y)

# %%
#print (log_reg.intercept_, log_reg.coef_)

# %%
def logReg(data):
  alpha = 0.001
  F = lambda W, X: sum([w*x for w,x in zip(W,X)])
  sigmoid = lambda y: 1/(1+math.exp(-y))
  classify = lambda y: 1 if y>0.5 else 0

  w = [0,0,0]

  X = [(d[0], d[1], d[2]) for d,_ in data]

  Y = [y for _, y in data]
  for _ in range(2000):
    yPredicted = [sigmoid(F(w, x)) for x in X]
    deltaX0 = sum( [((r-y)*x[0]) for r,y,x in zip(Y, yPredicted, X)] )
    deltaX1 = sum( [((r-y)*x[1]) for r,y,x in zip(Y, yPredicted, X)] )
    deltaX2 = sum( [((r-y)*x[2]) for r,y,x in zip(Y, yPredicted, X)] )
    
    w = [w[0]+alpha*deltaX0, w[1]+alpha*deltaX1, w[2]+alpha*deltaX2]

  print("Model=",w)
  
  for x,y in zip(X, Y):
    print ("x,r,y=", x, y, sigmoid(F(w,x)), round(sigmoid(F(w,x)), 3), classify(sigmoid(F(w,x))))

print("\nModel for data0")
logReg(data0)
print("\nModel for data0")
logReg(data1)
print("\nModel for data0")
logReg(data2)
print("\nModel for data0")
logReg(data3)
# Out:
# Model for data0
# Model= [-1.3058386409718923, 0.8842554378674178, -0.42158320310447434]
# x,r,y= (1, 2, 3) 0 0.30958132377325376 0.31 0
# x,r,y= (1, 3, 4) 0 0.41595398295508207 0.416 0
# x,r,y= (1, 4, 5) 0 0.5307778117783039 0.531 1
# x,r,y= (1, 5, 6) 1 0.6424328979441148 0.642 1
# x,r,y= (1, 6, 7) 1 0.7405081923393672 0.741 1
# x,r,y= (1, 8, 9) 1 0.8780353958225962 0.878 1
#
# Model for data0
# Model= [1.4444422142685953, 2.516552844568768, -1.481636577643822]
# x,r,y= (1, 0, 0) 1 0.8091416113460502 0.809 1
# x,r,y= (1, 1, 7) 0 0.0016415671721016082 0.002 0
# x,r,y= (1, -3, -2) 0 0.04140991636559391 0.041 0
# x,r,y= (1, 8, 9) 1 0.9997367480655438 1.0 1
# x,r,y= (1, 4, 3) 1 0.9991468689216529 0.999 1
# x,r,y= (1, 5, -2) 1 0.9999999582046035 1.0 1
# x,r,y= (1, 0, 0) 1 0.8091416113460502 0.809 1
# x,r,y= (1, 6, 9) 1 0.9611726846573201 0.961 1
# x,r,y= (1, 4, 2) 1 0.9998059848814366 1.0 1
# x,r,y= (1, 1, -9) 1 0.9999999691991729 1.0 1
# x,r,y= (1, -7, 7) 0 2.9687392706755342e-12 0.0 0
# x,r,y= (1, 0, -1) 1 0.9491206505481597 0.949 1
# x,r,y= (1, 9, -4) 1 0.9999999999999083 1.0 1
# x,r,y= (1, 1, 0) 1 0.9813117471741301 0.981 1
# x,r,y= (1, -2, -5) 1 0.9785326171438165 0.979 1
# x,r,y= (1, 2, 3) 1 0.8841815125703915 0.884 1
# x,r,y= (1, -7, 2) 0 4.89671699257163e-09 0.0 0
# x,r,y= (1, -3, 0) 0 0.002226231501461925 0.002 0
# x,r,y= (1, 5, 0) 1 0.9999991907898969 1.0 1
# x,r,y= (1, 0, -3) 1 0.9972388744975679 0.997 1
# x,r,y= (1, -2, 3) 0 0.0003242818404930527 0.0 0
# x,r,y= (1, 9, 6) 1 0.9999997504480181 1.0 1
# x,r,y= (1, 0, -8) 1 0.9999983213766148 1.0 1
# x,r,y= (1, 0, 2) 0 0.1796337337979741 0.18 0
# x,r,y= (1, -8, 6) 0 1.0546628134972513e-12 0.0 0
# x,r,y= (1, 1, 9) 0 8.491845948933263e-05 0.0 0
# x,r,y= (1, 0, 5) 0 0.002563689990380936 0.003 0
# x,r,y= (1, -4, 9) 0 2.913492597526239e-10 0.0 0
# x,r,y= (1, 8, 2) 1 0.9999999917544472 1.0 1
# x,r,y= (1, 2, 6) 0 0.08224170234261637 0.082 0
#
# Model for data0
# Model= [0.4916107422621384, 1.8278639085070776, -0.9196603125918917]
# x,r,y= (1, 0, 0) 0 0.620485808581043 0.62 1
# x,r,y= (1, 1, 7) 0 0.0160140124844656 0.016 0
# x,r,y= (1, -3, -2) 0 0.040986580566113956 0.041 0
# x,r,y= (1, 8, 9) 1 0.9989284523986909 0.999 1
# x,r,y= (1, 4, 3) 1 0.9935939479164932 0.994 1
# x,r,y= (1, 5, -2) 1 0.9999895641268511 1.0 1
# x,r,y= (1, 0, 0) 0 0.620485808581043 0.62 1
# x,r,y= (1, 6, 9) 1 0.9601455714360465 0.96 1
# x,r,y= (1, 4, 2) 1 0.997436322992471 0.997 1
# x,r,y= (1, 1, -9) 1 0.9999749951929408 1.0 1
# x,r,y= (1, -7, 7) 0 7.2587455471421975e-09 0.0 0
# x,r,y= (1, 0, -1) 1 0.8039663449492179 0.804 1
# x,r,y= (1, 9, -4) 1 0.9999999988923522 1.0 1
# x,r,y= (1, 1, 0) 1 0.9104771294578594 0.91 1
# x,r,y= (1, -2, -5) 1 0.8075524703167879 0.808 1
# x,r,y= (1, 2, 3) 1 0.8003299173322689 0.8 1
# x,r,y= (1, -7, 2) 0 7.209053650724343e-07 0.0 0
# x,r,y= (1, -3, 0) 0 0.006746373240840689 0.007 0
# x,r,y= (1, 5, 0) 1 0.9999343383783541 1.0 1
# x,r,y= (1, 0, -3) 1 0.962694368024877 0.963 1
# x,r,y= (1, -2, 3) 0 0.0026697476335866485 0.003 0
# x,r,y= (1, 9, 6) 1 0.9999890747613035 1.0 1
# x,r,y= (1, 0, -8) 1 0.9996099686160701 1.0 1
# x,r,y= (1, 0, 2) 1 0.20624503011921544 0.206 0
# x,r,y= (1, -8, 6) 0 2.927074419814967e-09 0.0 0
# x,r,y= (1, 1, 9) 0 0.002579779688852312 0.003 0
# x,r,y= (1, 0, 5) 0 0.016195547032990074 0.016 0
# x,r,y= (1, -4, 9) 0 2.776823554631591e-07 0.0 0
# x,r,y= (1, 8, 2) 1 0.9999982834654597 1.0 1
# x,r,y= (1, 2, 6) 0 0.20251915897643757 0.203 0
#
# Model for data0
# Model= [0.015510122501884402, 1.3922329679852876, -0.9253483019798913]
# x,r,y= (1, 2, 7) 0 0.024663405375553962 0.025 0
# x,r,y= (1, 19, 72) 0 3.630572849344909e-18 0.0 0
# x,r,y= (1, -39, -20) 0 2.905925413905168e-16 0.0 0
# x,r,y= (1, 86, 95) 1 0.9999999999999851 1.0 1
# x,r,y= (1, 45, 37) 1 0.9999999999995492 1.0 1
# x,r,y= (1, 52, -23) 1 1.0 1.0 1
# x,r,y= (1, -8, -8) 0 0.023670578095704716 0.024 0
# x,r,y= (1, 67, 93) 1 0.999281572368536 0.999 1
# x,r,y= (1, 46, 21) 1 1.0 1.0 1
# x,r,y= (1, 18, -97) 1 1.0 1.0 1
# x,r,y= (1, -78, 70) 0 5.172853904040705e-76 0.0 0
# x,r,y= (1, -9, -17) 1 0.9614443689582189 0.961 1
# x,r,y= (1, 94, -40) 1 1.0 1.0 1
# x,r,y= (1, 11, -3) 1 0.9999999863033928 1.0 1
# x,r,y= (1, -24, -59) 1 0.999999999377619 1.0 1
# x,r,y= (1, 25, 33) 1 0.9864113739127917 0.986 1
# x,r,y= (1, -71, 23) 0 6.827566939375243e-53 0.0 0
# x,r,y= (1, -34, -7) 0 1.8286152725419117e-18 0.0 0
# x,r,y= (1, 55, -3) 1 1.0 1.0 1
# x,r,y= (1, -5, -33) 1 0.9999999999431632 1.0 1
# x,r,y= (1, -22, 38) 0 2.713168251207172e-29 0.0 0
# x,r,y= (1, 94, 66) 1 1.0 1.0 1
# x,r,y= (1, 4, -89) 1 1.0 1.0 1
# x,r,y= (1, -9, 26) 0 1.3069798885873745e-16 0.0 0
# x,r,y= (1, -83, 61) 0 2.029540339161488e-75 0.0 0
# x,r,y= (1, 19, 98) 0 1.2919924013386442e-28 0.0 0
# x,r,y= (1, -1, 55) 0 1.9908818563778986e-23 0.0 0
# x,r,y= (1, -43, 90) 0 6.896445814658904e-63 0.0 0
# x,r,y= (1, 86, 27) 1 1.0 1.0 1
# x,r,y= (1, 24, 69) 0 6.148817700111389e-14 0.0 0
